# %% [markdown]
# <a href="https://colab.research.google.com/github/MichalSien/Michal-Lab/blob/main/LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math  as m
import numpy as np

# liczby losowe
import random

# grafika do wykresów
import matplotlib.pyplot as plt
import matplotlib as mpl

# działania na łańcuchach znaków
import string 

# statystyka
import statistics as st

# pomar czasu
import time

# dopasowywanie krzywych do danych
from scipy.optimize import curve_fit

# wyświetlanie importowanej grafiki
from IPython.display import display, Image

# wykresy konturowe
import matplotlib.cm as cm

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib as mpl

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %%
def kwadrat():
    x1=random.random()
    x2=random.random()
    if(0.05 < (x1-0.75)*(x1-0.25))+(x2-0.75)*(x2-0.25) < 0.05:
        return np.array([x1,x2,1])
    else:
        return np.array([x1,x2,0])

# %%
probka_k=np.array([kwadrat() for i in range(6000)])
print(probka_k.shape)
# Out:
# (6000, 3)

# %%
def draw_result(X,y): 
  fig=plt.figure(figsize=(5,5))

  # dorysowanie okręgu
  #ax=fig.add_subplot(1,1,1)
  #circ=plt.Circle((0.5,0.5), radius=.4, color='black', fill=False)
  #ax.add_patch(circ)

  plt.title("Działanie na próbce testowej",fontsize=16) 
  plt.xlim(min(X[:,0]),max(X[:,0]))
  plt.ylim(min(X[:,1]),max(X[:,1]))
  plt.scatter(X[:,0],X[:,1],c=y,
            s=5,cmap=mpl.cm.cool,norm=mpl.colors.Normalize(vmin=min(y), vmax=max(y)))

  plt.xlabel('$x_1$',fontsize=18)
  plt.ylabel('$x_2$',fontsize=18);

# %%
X, y = probka_k[:,:2], probka_k[:,2]

X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5, random_state=42)

print("Shapes of datasets X_train, X_test, y_train, y_test: ",X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#narysuj dane testowe
draw_result(X_test, y_test)
# Out:
# Shapes of datasets X_train, X_test, y_train, y_test:  (3000, 2) (3000, 2) (3000,) (3000,)

# %%
clf = MLPClassifier(hidden_layer_sizes=(5,5), activation='tanh', alpha=0.1, 
                    learning_rate_init=0.01, early_stopping=True,validation_fraction=0.2,verbose=True,n_iter_no_change=100,max_iter=1000)
                    #max_iter=1000) 


print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# get prediction
Z = clf.predict_proba(X_test)[:,1] # returns probability 
print(Z)
# Out:
# Iteration 1, loss = 0.70767811
# Validation score: 0.493333
# Iteration 2, loss = 0.66654881
# Validation score: 0.571667
# Iteration 3, loss = 0.65051062
# Validation score: 0.573333
# Iteration 4, loss = 0.63042254
# Validation score: 0.685000
# Iteration 5, loss = 0.60208016
# Validation score: 0.805000
# Iteration 6, loss = 0.56537559
# Validation score: 0.856667
# Iteration 7, loss = 0.52620124
# Validation score: 0.880000
# Iteration 8, loss = 0.48546457
# Validation score: 0.885000
# Iteration 9, loss = 0.44887789
# Validation score: 0.896667
# Iteration 10, loss = 0.41409236
# Validation score: 0.921667
# Iteration 11, loss = 0.38245241
# Validation score: 0.908333
# Iteration 12, loss = 0.35438559
# Validation score: 0.923333
# Iteration 13, loss = 0.33021721
# Validation score: 0.941667
# Iteration 14, loss = 0.30670611
# Validation score: 0.926667
# Iteration 15, loss = 0.28566207
# Validation score: 0.940000
# Iteration 16, loss = 0.26451861
# Validation score: 0.946667
# Iteration 17, loss = 0.24405053
# Validation score: 0.955000
# Iteration 18, loss = 0.22660745
# Validation score: 0.945000
# Iteration 19, loss = 0.20933972
# Validation score: 0.951667
# Iteration 20, loss = 0.19752637
# Validation score: 0.953333
# Iteration 21, loss = 0.18539555
# Validation score: 0.956667
# Iteration 22, loss = 0.18011164
# Validation score: 0.956667
# Iteration 23, loss = 0.16931271
# Validation score: 0.953333
# Iteration 24, loss = 0.16329139
# Validation score: 0.958333
# Iteration 25, loss = 0.15951026
# Validation score: 0.950000
# Iteration 26, loss = 0.15605012
# Validation score: 0.960000
# Iteration 27, loss = 0.15184114
# Validation score: 0.971667
# Iteration 28, loss = 0.14437400
# Validation score: 0.965000
# Iteration 29, loss = 0.13898291
# Validation score: 0.968333
# Iteration 30, loss = 0.13642424
# Validation score: 0.968333
# Iteration 31, loss = 0.13333501
# Validation score: 0.965000
# Iteration 32, loss = 0.13067514
# Validation score: 0.971667
# Iteration 33, loss = 0.12748732
# Validation score: 0.973333
# Iteration 34, loss = 0.12623268
# Validation score: 0.970000
# Iteration 35, loss = 0.12230698
# Validation score: 0.975000
# Iteration 36, loss = 0.11943083
# Validation score: 0.978333
# Iteration 37, loss = 0.11835483
# Validation score: 0.975000
# Iteration 38, loss = 0.11593709
# Validation score: 0.971667
# Iteration 39, loss = 0.11815916
# Validation score: 0.973333
# Iteration 40, loss = 0.11431542
# Validation score: 0.973333
# Iteration 41, loss = 0.11033517
# Validation score: 0.981667
# Iteration 42, loss = 0.10742104
# Validation score: 0.978333
# Iteration 43, loss = 0.10629594
# Validation score: 0.980000
# Iteration 44, loss = 0.10617017
# Validation score: 0.966667
# Iteration 45, loss = 0.10612207
# Validation score: 0.975000
# Iteration 46, loss = 0.10538590
# Validation score: 0.978333
# Iteration 47, loss = 0.10479579
# Validation score: 0.980000
# Iteration 48, loss = 0.10117556
# Validation score: 0.985000
# Iteration 49, loss = 0.10080720
# Validation score: 0.986667
# Iteration 50, loss = 0.10095899
# Validation score: 0.978333
# Iteration 51, loss = 0.10174412
# Validation score: 0.981667
# Iteration 52, loss = 0.10027372
# Validation score: 0.986667
# Iteration 53, loss = 0.09699109
# Validation score: 0.980000
# Iteration 54, loss = 0.09698544
# Validation score: 0.973333
# Iteration 55, loss = 0.10481333
# Validation score: 0.973333
# Iteration 56, loss = 0.09971092
# Validation score: 0.985000
# Iteration 57, loss = 0.09339227
# Validation score: 0.981667
# Iteration 58, loss = 0.09603451
# Validation score: 0.988333
# Iteration 59, loss = 0.09507396
# Validation score: 0.981667
# Iteration 60, loss = 0.09637387
# Validation score: 0.981667
# Iteration 61, loss = 0.09341414
# Validation score: 0.983333
# Iteration 62, loss = 0.09347589
# Validation score: 0.981667
# Iteration 63, loss = 0.09246196
# Validation score: 0.983333
# Iteration 64, loss = 0.09102105
# Validation score: 0.988333
# Iteration 65, loss = 0.09127526
# Validation score: 0.983333
# Iteration 66, loss = 0.09137459
# Validation score: 0.983333
# Iteration 67, loss = 0.09298128
# Validation score: 0.978333
# Iteration 68, loss = 0.09260646
# Validation score: 0.988333
# Iteration 69, loss = 0.09429183
# Validation score: 0.990000
# Iteration 70, loss = 0.09117387
# Validation score: 0.988333
# Iteration 71, loss = 0.09188337
# Validation score: 0.981667
# Iteration 72, loss = 0.09098536
# Validation score: 0.985000
# Iteration 73, loss = 0.09090613
# Validation score: 0.986667
# Iteration 74, loss = 0.08915299
# Validation score: 0.988333
# Iteration 75, loss = 0.08872837
# Validation score: 0.988333
# Iteration 76, loss = 0.08739419
# Validation score: 0.980000
# Iteration 77, loss = 0.08624984
# Validation score: 0.991667
# Iteration 78, loss = 0.08791574
# Validation score: 0.990000
# Iteration 79, loss = 0.08593886
# Validation score: 0.985000
# Iteration 80, loss = 0.09018477
# Validation score: 0.988333
# Iteration 81, loss = 0.08780018
# Validation score: 0.993333
# Iteration 82, loss = 0.08602211
# Validation score: 0.986667
# Iteration 83, loss = 0.08688609
# Validation score: 0.980000
# Iteration 84, loss = 0.08906071
# Validation score: 0.986667
# Iteration 85, loss = 0.08575062
# Validation score: 0.988333
# Iteration 86, loss = 0.08501423
# Validation score: 0.988333
# Iteration 87, loss = 0.08544838
# Validation score: 0.990000
# Iteration 88, loss = 0.08535629
# Validation score: 0.983333
# Iteration 89, loss = 0.08404057
# Validation score: 0.985000
# Iteration 90, loss = 0.08323167
# Validation score: 0.995000
# Iteration 91, loss = 0.08479974
# Validation score: 0.991667
# Iteration 92, loss = 0.08480908
# Validation score: 0.991667
# Iteration 93, loss = 0.08431729
# Validation score: 0.990000
# Iteration 94, loss = 0.08406171
# Validation score: 0.986667
# Iteration 95, loss = 0.08293445
# Validation score: 0.985000
# Iteration 96, loss = 0.08297385
# Validation score: 0.991667
# Iteration 97, loss = 0.08334042
# Validation score: 0.986667
# Iteration 98, loss = 0.08342565
# Validation score: 0.988333
# Iteration 99, loss = 0.08332697
# Validation score: 0.981667
# Iteration 100, loss = 0.08431927
# Validation score: 0.990000
# Iteration 101, loss = 0.08322457
# Validation score: 0.995000
# Iteration 102, loss = 0.08193981
# Validation score: 0.990000
# Iteration 103, loss = 0.08447032
# Validation score: 0.991667
# Iteration 104, loss = 0.08288238
# Validation score: 0.988333
# Iteration 105, loss = 0.08238059
# Validation score: 0.991667
# Iteration 106, loss = 0.08265454
# Validation score: 0.988333
# Iteration 107, loss = 0.08127441
# Validation score: 0.991667
# Iteration 108, loss = 0.08327939
# Validation score: 0.988333
# Iteration 109, loss = 0.08086599
# Validation score: 0.996667
# Iteration 110, loss = 0.08282709
# Validation score: 0.993333
# Iteration 111, loss = 0.08226569
# Validation score: 0.980000
# Iteration 112, loss = 0.08191144
# Validation score: 0.990000
# Iteration 113, loss = 0.08146784
# Validation score: 0.991667
# Iteration 114, loss = 0.08248116
# Validation score: 0.986667
# Iteration 115, loss = 0.08546341
# Validation score: 0.980000
# Iteration 116, loss = 0.08601363
# Validation score: 0.988333
# Iteration 117, loss = 0.08112365
# Validation score: 0.995000
# Iteration 118, loss = 0.08118172
# Validation score: 0.991667
# Iteration 119, loss = 0.08153266
# Validation score: 0.991667
# Iteration 120, loss = 0.08144258
# Validation score: 0.985000
# Iteration 121, loss = 0.08626445
# Validation score: 0.991667
# Iteration 122, loss = 0.08153477
# Validation score: 0.983333
# Iteration 123, loss = 0.08247545
# Validation score: 0.991667
# Iteration 124, loss = 0.08673414
# Validation score: 0.986667
# Iteration 125, loss = 0.08433672
# Validation score: 0.990000
# Iteration 126, loss = 0.08565895
# Validation score: 0.978333
# Iteration 127, loss = 0.08350107
# Validation score: 0.985000
# Iteration 128, loss = 0.08349487
# Validation score: 0.990000
# Iteration 129, loss = 0.08281509
# Validation score: 0.995000
# Iteration 130, loss = 0.08305955
# Validation score: 0.983333
# Iteration 131, loss = 0.08049073
# Validation score: 0.991667
# Iteration 132, loss = 0.07983324
# Validation score: 0.993333
# Iteration 133, loss = 0.07843103
# Validation score: 0.988333
# Iteration 134, loss = 0.07909484
# Validation score: 0.988333
# Iteration 135, loss = 0.07928002
# Validation score: 0.993333
# Iteration 136, loss = 0.07850432
# Validation score: 0.991667
# Iteration 137, loss = 0.07963542
# Validation score: 0.988333
# Iteration 138, loss = 0.08077796
# Validation score: 0.991667
# Iteration 139, loss = 0.07954378
# Validation score: 0.988333
# Iteration 140, loss = 0.07848895
# Validation score: 0.986667
# Iteration 141, loss = 0.07934690
# Validation score: 0.991667
# Iteration 142, loss = 0.07890784
# Validation score: 0.995000
# Iteration 143, loss = 0.08154051
# Validation score: 0.988333
# Iteration 144, loss = 0.07902380
# Validation score: 0.991667
# Iteration 145, loss = 0.07885893
# Validation score: 0.993333
# Iteration 146, loss = 0.07911387
# Validation score: 0.993333
# Iteration 147, loss = 0.07889524
# Validation score: 0.985000
# Iteration 148, loss = 0.08175597
# Validation score: 0.990000
# Iteration 149, loss = 0.08010993
# Validation score: 0.990000
# Iteration 150, loss = 0.07910649
# Validation score: 0.986667
# Iteration 151, loss = 0.07894396
# Validation score: 0.991667
# Iteration 152, loss = 0.07903447
# Validation score: 0.996667
# Iteration 153, loss = 0.08026053
# Validation score: 0.993333
# Iteration 154, loss = 0.08087708
# Validation score: 0.985000
# Iteration 155, loss = 0.07906349
# Validation score: 0.991667
# Iteration 156, loss = 0.08031317
# Validation score: 0.993333
# Iteration 157, loss = 0.08095147
# Validation score: 0.990000
# Iteration 158, loss = 0.08011245
# Validation score: 0.991667
# Iteration 159, loss = 0.07868372
# Validation score: 0.990000
# Iteration 160, loss = 0.07893193
# Validation score: 0.995000
# Iteration 161, loss = 0.07867926
# Validation score: 0.986667
# Iteration 162, loss = 0.07843862
# Validation score: 0.986667
# Iteration 163, loss = 0.08101816
# Validation score: 0.990000
# Iteration 164, loss = 0.07788936
# Validation score: 0.996667
# Iteration 165, loss = 0.08076617
# Validation score: 0.983333
# Iteration 166, loss = 0.08061814
# Validation score: 0.990000
# Iteration 167, loss = 0.07887120
# Validation score: 0.990000
# Iteration 168, loss = 0.07866347
# Validation score: 0.985000
# Iteration 169, loss = 0.08019298
# Validation score: 0.993333
# Iteration 170, loss = 0.07784887
# Validation score: 0.990000
# Iteration 171, loss = 0.07785149
# Validation score: 0.991667
# Iteration 172, loss = 0.07817817
# Validation score: 0.996667
# Iteration 173, loss = 0.07759234
# Validation score: 0.988333
# Iteration 174, loss = 0.07723754
# Validation score: 0.991667
# Iteration 175, loss = 0.07705213
# Validation score: 0.995000
# Iteration 176, loss = 0.07894718
# Validation score: 0.990000
# Iteration 177, loss = 0.07906103
# Validation score: 0.980000
# Iteration 178, loss = 0.08011709
# Validation score: 0.995000
# Iteration 179, loss = 0.07753727
# Validation score: 0.990000
# Iteration 180, loss = 0.07875036
# Validation score: 0.995000
# Iteration 181, loss = 0.07950746
# Validation score: 0.988333
# Iteration 182, loss = 0.07696521
# Validation score: 0.996667
# Iteration 183, loss = 0.07762264
# Validation score: 0.985000
# Iteration 184, loss = 0.07687608
# Validation score: 0.990000
# Iteration 185, loss = 0.07762714
# Validation score: 0.993333
# Iteration 186, loss = 0.07801748
# Validation score: 0.990000
# Iteration 187, loss = 0.07922051
# Validation score: 0.991667
# Iteration 188, loss = 0.07895179
# Validation score: 0.983333
# Iteration 189, loss = 0.07710860
# Validation score: 0.995000
# Iteration 190, loss = 0.07667206
# Validation score: 0.988333
# Iteration 191, loss = 0.07670828
# Validation score: 0.996667
# Iteration 192, loss = 0.07609787
# Validation score: 0.988333
# Iteration 193, loss = 0.07926032
# Validation score: 0.986667
# Iteration 194, loss = 0.07884274
# Validation score: 0.986667
# Iteration 195, loss = 0.07909551
# Validation score: 0.993333
# Iteration 196, loss = 0.07874976
# Validation score: 0.993333
# Iteration 197, loss = 0.07662163
# Validation score: 0.991667
# Iteration 198, loss = 0.07637480
# Validation score: 0.993333
# Iteration 199, loss = 0.07675631
# Validation score: 0.995000
# Iteration 200, loss = 0.07720387
# Validation score: 0.991667
# Iteration 201, loss = 0.07679447
# Validation score: 0.990000
# Iteration 202, loss = 0.07679474
# Validation score: 0.988333
# Iteration 203, loss = 0.07675514
# Validation score: 0.988333
# Iteration 204, loss = 0.07949052
# Validation score: 0.993333
# Iteration 205, loss = 0.07709004
# Validation score: 0.990000
# Iteration 206, loss = 0.07840628
# Validation score: 0.993333
# Iteration 207, loss = 0.07578193
# Validation score: 0.993333
# Iteration 208, loss = 0.07663593
# Validation score: 0.993333
# Iteration 209, loss = 0.07661295
# Validation score: 0.993333
# Iteration 210, loss = 0.07734210
# Validation score: 0.993333
# Validation score did not improve more than tol=0.000100 for 100 consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(5, 5), learning_rate='constant',
#               learning_rate_init=0.01, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=100, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=True,
#               warm_start=False)
# Score =  0.988
# [0.9999932  0.95049719 0.34175749 ... 0.00319569 0.00107235 0.99922542]
